# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io, color

print("Imports OK")
# Out:
# Imports OK

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\aleca\anaconda3\envs\organoid\python.exe

# %%
import pandas as pd
import cv2
print("pandas + cv2 OK")
# Out:
# pandas + cv2 OK
